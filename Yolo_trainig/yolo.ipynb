# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rK7UN9J72kBKdKI0bzDh")
project = rf.workspace("newton-zdy8s").project("remy-fb4aw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to REMY-1 in yolov8::   9%|▉         | 5769/63396 [00:01<00:13, 4241.15it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 7
#       5 project = rf.workspace("newton-zdy8s").project("remy-fb4aw")
#       6 version = project.version(1)
# ----> 7 dataset = version.download("yolov8")
#
# File ~/venvs/data_science/lib/python3.10/site-packages/roboflow/core/version.py:242, in Version.download(self, model_format, location, overwrite)
#     239     link = export_info["export"]["link"]
#     241 self.__download_zip(link, location, model_format)
# --> 242 self.__extract_zip(location, model_format)
#     243 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
# ...

# %%
import ultralytics
model = ultralytics.YOLO('runs/detect/treinada (falta bandeja)6/weights/best.pt')
model.train(
    data='REMY-1/data.yaml',
    epochs=50,
    imgsz=640,
    val=False,
    batch=16,
    name='treinada (falta bandeja)'  # Nome para a pasta de resultados
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.184 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.178 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 3902MiB)
# ...
