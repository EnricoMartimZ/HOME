# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rK7UN9J72kBKdKI0bzDh")
project = rf.workspace("newton-zdy8s").project("remy-fb4aw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Requirement already satisfied: roboflow in /home/pc/venvs/data_science/lib/python3.10/site-packages (1.2.6)
# Requirement already satisfied: certifi in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: idna==3.7 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (3.10.5)
# Requirement already satisfied: numpy>=1.18.5 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (2.28.1)
# Requirement already satisfied: six in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.26.13)
# Requirement already satisfied: tqdm>=4.41.0 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/pc/venvs/data_science/lib/python3.10/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/pc/venvs/data_science/lib/python3.10/site-packages (from requests->roboflow) (2.1.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in REMY-1 to yolov8:: 100%|██████████| 2990947/2990947 [02:04<00:00, 24120.46it/s]
# Extracting Dataset Version Zip to REMY-1 in yolov8:: 100%|██████████| 63396/63396 [00:05<00:00, 11617.24it/s]

# %%
import ultralytics
model = ultralytics.YOLO('yolov8n.pt')
model.train(
    data='REMY-1/data.yaml',
    epochs=50,
    imgsz=640,
    val=False,
    batch=16,
    name='treinada (falta bandeja)'  # Nome para a pasta de resultados
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.187 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.178 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2050, 3902MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=REMY-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=treinada (falta bandeja)3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/treinada (falta bandeja)3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=False, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753262  ultralytics.nn.modules.head.Detect           [10, [64, 128, 256]]
# Model summary: 129 layers, 3,012,798 parameters, 3,012,782 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100%|██████████| 5.35M/5.35M [00:00<00:00, 20.0MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3707.7±1455.4 MB/s, size: 56.9 KB)
# train: Scanning /home/pc/Documents/GitHub/HOME/Yolo_trainig/REMY-1/train/labels... 31695 images, 662 backgrounds, 0 corrupt: 100%|██████████| 31695/31695 [00:10<00:00, 3037.12it/s]
# train: New cache created: /home/pc/Documents/GitHub/HOME/Yolo_trainig/REMY-1/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 624, len(boxes) = 33775. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2558.5±1247.2 MB/s, size: 105.6 KB)
# val: Scanning /home/pc/Documents/GitHub/HOME/Yolo_trainig/REMY-1/train/labels.cache... 31695 images, 662 backgrounds, 0 corrupt: 100%|██████████| 31695/31695 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 624, len(boxes) = 33775. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/treinada (falta bandeja)3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/treinada (falta bandeja)3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.99G       1.07      3.988      1.233         28        640:  10%|█         | 206/1981 [00:48<06:56,  4.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import ultralytics
#       2 model = ultralytics.YOLO('yolov8n.pt')
# ----> 3 model.train(
#       4     data='REMY-1/data.yaml',
#       5     epochs=50,
#       6     imgsz=640,
#       7     val=False,
#       8     batch=16,
#       9     name='treinada (falta bandeja)'  # Nome para a pasta de resultados
#      10 )
#
# File ~/venvs/data_science/lib/python3.10/site-packages/ultralytics/engine/model.py:799, in Model.train(self, trainer, **kwargs)
#     796     self.model = self.trainer.model
#     798 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799 self.trainer.train()
#     800 # Update model and cfg after training
#     801 if RANK in {-1, 0}:
#
# File ~/venvs/data_science/lib/python3.10/site-packages/ultralytics/engine/trainer.py:227, in BaseTrainer.train(self)
#     224         ddp_cleanup(self, str(file))
#     226 else:
# --> 227     self._do_train(world_size)
#
# File ~/venvs/data_science/lib/python3.10/site-packages/ultralytics/engine/trainer.py:419, in BaseTrainer._do_train(self, world_size)
#     417 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     418 if ni - last_opt_step >= self.accumulate:
# --> 419     self.optimizer_step()
#     420     last_opt_step = ni
#     422     # Timed stopping
#
# File ~/venvs/data_science/lib/python3.10/site-packages/ultralytics/engine/trainer.py:641, in BaseTrainer.optimizer_step(self)
#     639 """Perform a single step of the training optimizer with gradient clipping and EMA update."""
#     640 self.scaler.unscale_(self.optimizer)  # unscale gradients
# --> 641 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)  # clip gradients
#     642 self.scaler.step(self.optimizer)
#     643 self.scaler.update()
#
# File ~/venvs/data_science/lib/python3.10/site-packages/torch/nn/utils/clip_grad.py:30, in _no_grad.<locals>._no_grad_wrapper(*args, **kwargs)
#      28 def _no_grad_wrapper(*args, **kwargs):
#      29     with torch.no_grad():
# ---> 30         return func(*args, **kwargs)
#
# File ~/venvs/data_science/lib/python3.10/site-packages/torch/nn/utils/clip_grad.py:94, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite, foreach)
#      91     else:
#      92         norms.extend([torch.linalg.vector_norm(g, norm_type) for g in device_grads])
# ---> 94 total_norm = torch.linalg.vector_norm(
#      95     torch.stack([norm.to(first_device) for norm in norms]), norm_type
#      96 )
#      98 if error_if_nonfinite and torch.logical_or(total_norm.isnan(), total_norm.isinf()):
#      99     raise RuntimeError(
#     100         f"The total norm of order {norm_type} for gradients from "
#     101         "`parameters` is non-finite, so it cannot be clipped. To disable "
#     102         "this error and scale the gradients by the non-finite norm anyway, "
#     103         "set `error_if_nonfinite=False`"
#     104     )
#
# KeyboardInterrupt:
